# %%
# !pip install yfinance

# %%
import yfinance as yf
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
start_date = "2015-01-01"
today = datetime.now()
tomorrow = today + timedelta(days=1)

# %%
def lineplot_stock(data, ticker):
    _, axes = plt.subplots(2, 1, figsize=(15, 7))

    axes[0].plot(data.index, data['Close'])
    axes[0].plot(data.index, data['Open'])
    axes[0].plot(data.index, data['High'])
    axes[0].plot(data.index, data['Low'])
    # axes[0].legend(data.columns)
    axes[0].grid("True")

    axes[1].plot(data.index, data['Volume'])
    # axes[1].legend(data.columns)
    axes[1].grid("True")

    plt.suptitle(ticker + " Stock Price", y=0.95, fontsize=18)

def remove_ticker(data):
    data.columns = [col[0] for col in data.columns]
    return data

# %%
Ticker = ['AAPL', 'GOOG', 'MSFT']

# %% [markdown]
# # AAPL - Apple Inc.

# %%
aapl_data = yf.download(Ticker[2], start=start_date, end=tomorrow)
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['MSFT']: JSONDecodeError('Expecting value: line 1 column 1 (char 0)')

# %%
aapl_data.index
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2025-01-06', '2025-01-07', '2025-01-08', '2025-01-10',
#                '2025-01-13', '2025-01-14', '2025-01-15', '2025-01-16',
#                '2025-01-17', '2025-01-21'],
#               dtype='datetime64[ns]', name='Date', length=2528, freq=None)

# %%
aapl_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2528 entries, 2015-01-02 to 2025-01-21
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, AAPL)   2528 non-null   float64
#  1   (High, AAPL)    2528 non-null   float64
#  2   (Low, AAPL)     2528 non-null   float64
#  3   (Open, AAPL)    2528 non-null   float64
#  4   (Volume, AAPL)  2528 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 118.5 KB

# %%
aapl_data = remove_ticker(aapl_data)

# %%
lineplot_stock(aapl_data, Ticker[0])

# %% [markdown]
# # GOOG - Google

# %%
goog_data = yf.download("GOOG", start=start_date, end=tomorrow)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
goog_data = remove_ticker(goog_data)

# %%
lineplot_stock(goog_data, Ticker[1])

# %% [markdown]
# # MSFT - Microsoft

# %%
msft_data = yf.download("MSFT", start=start_date, end=tomorrow)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
msft_data = remove_ticker(msft_data)

# %%
lineplot_stock(msft_data, Ticker[2])

# %%
aapl_data.to_csv('../data/aapl_stock_price.csv', index=True)
goog_data.to_csv('../data/goog_stock_price.csv', index=True)
msft_data.to_csv('../data/msft_stock_price.csv', index=True)

# %% [markdown]
# # BBCA.JK - Bank Central Asia

# %%
# Ambil objek ticker
ticker = yf.Ticker('GOOG')

# Ambil data historis penuh
data = ticker.history(period='1mo')
# Out:
# $GOOG: possibly delisted; no price data found  (period=1mo)

# %%
data
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
# !pip install investpy-reborn
# Out:
# ERROR: Could not find a version that satisfies the requirement investpy-reborn (from versions: none)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for investpy-reborn

# %%
import investpy

data = investpy.get_stock_historical_data(
    stock='BBCA',
    country='indonesia',
    from_date='01/01/2023',
    to_date='06/04/2025'
)

print(data.tail())
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[17], line 3
#       1 import investpy
# ----> 3 data = investpy.get_stock_historical_data(
#       4     stock='BBCA',
#       5     country='indonesia',
#       6     from_date='01/01/2023',
#       7     to_date='06/04/2025'
#       8 )
#      10 print(data.tail())
#
# File c:\Users\fadhil\AppData\Local\Programs\Python\Python312\Lib\site-packages\investpy\stocks.py:664, in get_stock_historical_data(stock, country, from_date, to_date, as_json, order, interval)
#     661 req = requests.post(url, headers=head, data=params)
#     663 if req.status_code != 200:
# --> 664     raise ConnectionError(
#     665         "ERR#0015: error " + str(req.status_code) + ", try again later."
#     666     )
#     668 if not req.text:
#     669     continue
#
# ConnectionError: ERR#0015: error 403, try again later.
