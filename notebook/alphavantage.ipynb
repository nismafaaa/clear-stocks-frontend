# %%
import requests
import pandas as pd

# %%
ALPHAVANTAGE_KEY = "CZ3TU330NRCDUJP7"
symbol = 'BBCA.JK'

# %% [markdown]
# # Get Stock Data

# %%
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={symbol}&apikey={ALPHAVANTAGE_KEY}&outputsize=full'
r = requests.get(url)
data = r.json()

# %%
data
# Out:
# {'Error Message': 'Invalid API call. Please retry or visit the documentation (https://www.alphavantage.co/documentation/) for TIME_SERIES_DAILY.'}

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={symbol}&apikey={ALPHAVANTAGE_KEY}'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Error Message': 'Invalid API call. Please retry or visit the documentation (https://www.alphavantage.co/documentation/) for TIME_SERIES_DAILY.'}

# %% [markdown]
# # Symbol Search

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'https://www.alphavantage.co/query?function=SYMBOL_SEARCH&keywords={symbol}&apikey={ALPHAVANTAGE_KEY}'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'bestMatches': []}

# %% [markdown]
# # idx.co.id
